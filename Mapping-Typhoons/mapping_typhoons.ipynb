# %%
import numpy as np
from climada.hazard.tc_tracks import TCTracks
from climada.hazard import TropCyclone
from climada.hazard import Centroids
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Detailed information about storms can be found in this website: https://ncics.org/ibtracs/index.php?name=browse-year-basin

# %% [markdown]
# ### 2010

# %%
tracks_2010 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2010, 2010))
# Out:
# 2025-01-05 23:26:15,386 - climada.hazard.tc_tracks - WARNING - 1 storm events are discarded because no valid wind/pressure values have been found: 2010200N26127.

# %%
print(tracks_2010.size)
# Out:
# 21

# %%
tracks_2010.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon MEGI (2010285N13145), IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2010285N13145 Wiki: https://en.wikipedia.org/wiki/Typhoon_Megi_(2010)

# %% [markdown]
# ### 2011

# %%
tracks_2011 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2011, 2011))
# Out:
# 2025-01-05 23:01:03,482 - climada.hazard.tc_tracks - WARNING - 1 storm events are discarded because no valid wind/pressure values have been found: 2011151N19116.

# %%
print(tracks_2011.size)
# Out:
# 27

# %%
tracks_2011.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon SONGDA, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2011140N08142 Wiki: https://en.wikipedia.org/wiki/Typhoon_Songda_(2011)

# %% [markdown]
# Cat 5: Super Typhoon NANMADOL, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2011233N12129 Wiki: https://en.wikipedia.org/wiki/Typhoon_Nanmadol_(2011)

# %% [markdown]
# ### 2012

# %%
tracks_2012 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2012, 2012))

# %%
print(tracks_2012.size)
# Out:
# 27

# %%
tracks_2012.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon BOPHA, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2012331N03157, Wiki: https://en.wikipedia.org/wiki/Typhoon_Bopha

# %% [markdown]
# ### 2013

# %%
tracks_2013 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2013, 2013))
# Out:
# 2025-01-14 11:14:35,418 - climada.hazard.tc_tracks - WARNING - 1 storm events are discarded because no valid wind/pressure values have been found: 2013241N29169.

# %%
print(tracks_2013.size)
# Out:
# 36

# %%
tracks_2013.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon HAIYAN, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2013306N07162 Wiki: https://en.wikipedia.org/wiki/Typhoon_Haiyan

# %% [markdown]
# Cat 5: Super Typhoon LEKIMA, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2013292N09162 Wiki: https://en.wikipedia.org/wiki/Typhoon_Lekima

# %% [markdown]
# ### 2014

# %%
tracks_2014 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2014, 2014))
# Out:
# 2025-01-14 11:35:39,378 - climada.hazard.tc_tracks - WARNING - 2 storm events are discarded because no valid wind/pressure values have been found: 2014160N21120, 2014231N21117.

# %%
print(tracks_2014.size)
# Out:
# 24

# %%
tracks_2014.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon RAMMASUN, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2014190N08154 Wiki: https://en.wikipedia.org/wiki/Typhoon_Rammasun

# %% [markdown]
# ### 2015

# %%
tracks_2015 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2015, 2015))

# %%
print(tracks_2015.size)
# Out:
# 32

# %%
tracks_2015.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon GONI, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2015226N12151 Wiki: https://en.wikipedia.org/wiki/Typhoon_Goni

# %% [markdown]
# ### 2016

# %%
tracks_2016 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2016, 2016))
# Out:
# 2025-01-14 13:01:55,624 - climada.hazard.tc_tracks - WARNING - 2 storm events are discarded because no valid wind/pressure values have been found: 2016250N25125, 2016347N10110.

# %%
print(tracks_2016.size)
# Out:
# 30

# %%
tracks_2016.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon NEPARTAK, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2016185N08145 Wiki: https://en.wikipedia.org/wiki/Typhoon_Nepartak

# %% [markdown]
# Cat 5: Super Typhoon NOCK-TEN, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2016355N07146, Wiki: https://en.wikipedia.org/wiki/Typhoon_Nock-ten

# %% [markdown]
# Cat 5: Super Typhoon HAIMA, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2016288N06146, Wiki: https://en.wikipedia.org/wiki/Typhoon_Haima

# %% [markdown]
# ### 2017

# %%
tracks_2017 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2017, 2017))
# Out:
# 2025-01-14 13:58:46,339 - climada.hazard.tc_tracks - WARNING - 1 storm events are discarded because no valid wind/pressure values have been found: 2017305N08108.

# %%
print(tracks_2017.size)
# Out:
# 34

# %%
tracks_2017.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# ### 2018

# %%
tracks_2018 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2018, 2018))

# %%
print(tracks_2018.size)
# Out:
# 36

# %%
tracks_2018.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon JEBI, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2018239N11161 Wiki: https://en.wikipedia.org/wiki/Typhoon_Jebi

# %% [markdown]
# Cat 5: Super Typhoon MANGKHUT, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2018250N12170, Wiki: https://en.wikipedia.org/wiki/Typhoon_Mangkhut

# %% [markdown]
# ### 2019

# %%
tracks_2019 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2019, 2019))
# Out:
# 2025-01-14 14:25:38,677 - climada.hazard.tc_tracks - WARNING - 2 storm events are discarded because no valid wind/pressure values have been found: 2019176N18128, 2019250N24123.

# %%
print(tracks_2019.size)
# Out:
# 30

# %%
tracks_2019.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 4: Super Typhoon KAMMURI, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2019329N09160, Wiki: https://en.wikipedia.org/wiki/Typhoon_Kammuri

# %% [markdown]
# ### 2020

# %%
tracks_2020 = TCTracks.from_ibtracs_netcdf(provider='usa', basin='WP', year_range=(2020, 2020))
# Out:
# 2025-01-14 15:12:55,884 - climada.hazard.tc_tracks - WARNING - 2 storm events are discarded because no valid wind/pressure values have been found: 2020195N17125, 2020288N13124.

# %%
print(tracks_2020.size)
# Out:
# 26

# %%
tracks_2020.plot()
# Out:
# <GeoAxes: >

# %% [markdown]
# Cat 5: Super Typhoon GONI, IBTrACS: https://ncics.org/ibtracs/index.php?name=v04r01-2020299N11144, Wiki: https://en.wikipedia.org/wiki/Typhoon_Goni
